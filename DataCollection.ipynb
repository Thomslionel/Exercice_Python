# %%
import requests as rq
import pandas as pd

from bs4 import BeautifulSoup

# %%
url = "https://www.gov.uk/search/news-and-communications" 
page = rq.get(url)

# Voir le code html source
print(page.content)
# Out:
# b'<!DOCTYPE html>\n<!--[if lt IE 9]><html class="lte-ie8 govuk-template" lang="en"><![endif]--><!--[if gt IE 8]><!--><html class="govuk-template" lang="en">\n<!--<![endif]-->\n  <head>\n<meta http-equiv="Content-Type" content="text/html; charset=UTF-8">\n<meta property="og:description" content="Find news and communications from government">\n<meta property="og:title" content="News and communications">\n<meta property="og:url" content="https://www.gov.uk/search/news-and-communications">\n<meta property="og:type" content="article">\n<meta property="og:site_name" content="GOV.UK">\n<meta name="govuk:base_title" content="News and communications - GOV.UK">\n<meta name="govuk:search-result-count" content="128721">\n<meta name="twitter:card" content="summary">\n<meta name="govuk:public-updated-at" content="2021-02-09T10:00:56Z">\n<meta name="govuk:updated-at" content="2021-02-09T10:00:56Z">\n<meta name="govuk:first-published-at" content="2019-02-01T12:31:51Z">\n<meta name="govuk:static-anal
# ...

# %%
soup = BeautifulSoup(page.content, "html.parser")
soup
# Out:
# <!DOCTYPE html>
#
# <!--[if lt IE 9]><html class="lte-ie8 govuk-template" lang="en"><![endif]--><!--[if gt IE 8]><!--><html class="govuk-template" lang="en">
# <!--<![endif]-->
# <head>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta content="Find news and communications from government" property="og:description"/>
# <meta content="News and communications" property="og:title"/>
# <meta content="https://www.gov.uk/search/news-and-communications" property="og:url"/>
# <meta content="article" property="og:type"/>
# <meta content="GOV.UK" property="og:site_name"/>
# <meta content="News and communications - GOV.UK" name="govuk:base_title"/>
# <meta content="128721" name="govuk:search-result-count"/>
# <meta content="summary" name="twitter:card"/>
# <meta content="2021-02-09T10:00:56Z" name="govuk:public-updated-at"/>
# <meta content="2021-02-09T10:00:56Z" name="govuk:updated-at"/>
# <meta content="2019-02-01T12:31:51Z" name="govuk:first-published-at"/>
# ...

# %%
soup.title.string
# Out:
# 'News and communications - GOV.UK'

# %%
descriptions = soup.find_all("p", class_="gem-c-document-list__item-description")
descriptions
# Out:
# [<p class="gem-c-document-list__item-description">UK government joins G7 nations and calls for swift action to protect marine habitats and halt biodiversity loss</p>,
#  <p class="gem-c-document-list__item-description">AlphaTheta’s proposed deal to acquire Serato could also reduce innovation, choice, and access to DJ equipment and software.</p>,
#  <p class="gem-c-document-list__item-description">We are now accepting applications from PhD students for placements beginning in January 2025</p>,
#  <p class="gem-c-document-list__item-description">The King has been pleased to appoint Dr Derrick Anderson, CBE, DL, as His Majesty's Lord-Lieutenant for the ceremonial county of the West Midlands.</p>,
#  <p class="gem-c-document-list__item-description">The ABS proposals are a curriculum reform – they set a new vision for what students should learn post-16, at what level and with what balance across subjects. </p>,
# ...

# %%
titres_text = []

for titre in descriptions:
    titres_text.append(titre.string)

titres_text
# Out:
# ['UK government joins G7 nations and calls for swift action to protect marine habitats and halt biodiversity loss',
#  'AlphaTheta’s proposed deal to acquire Serato could also reduce innovation, choice, and access to DJ equipment and software.',
#  'We are now accepting applications from PhD students for placements beginning in January 2025',
#  "The King has been pleased to appoint Dr Derrick Anderson, CBE, DL, as His Majesty's Lord-Lieutenant for the ceremonial county of the West Midlands.",
#  'The ABS proposals are a curriculum reform – they set a new vision for what students should learn post-16, at what level and with what balance across subjects. ',
#  'The UK’s export credit agency has completed its first transaction in support of overseas offshore oil and gas decommissioning. ',
# ...

# %% [markdown]
# ### Fichier index.html, extraction d'informations et exercices

# %%
with open("index.html", "r") as file:
    soup = BeautifulSoup(file, "html.parser")

# Extraction du titre

titre = soup.title.string

# Extraction de h1

header_1 = soup.h1.string


# Extractions de li
products = []

produits = soup.find_all("li")
produits

# Extractions de h2 et de prix contenu dans p
for info in produits:
    name = info.h2.string
    price = info.find('p', string=lambda s: 'Prix' in s).string
    prices = pd.Series(price)
    prices = prices.str.replace("[â‚¬]", "",regex=True)
    extracted_numbers = prices.str.extract(r"(\d+)$")
    print(extracted_numbers)
    
    # print(len(prices))
    products.append((name, extracted_numbers))

# Extractions description contenu dans p

descriptions_list = []
for product in produits:
    description = product.find('p', string=lambda s: 'Description' in s).string
    descriptions_list.append(description)


# Étape 2 : Affichage des informations extraites
# print("Titre de la page :", titre)
# print("Texte de la balise h1 :", header_1)
# print("Liste des produits :", products)
# print("Liste des descriptions de produits :", descriptions_list)
# Out:
#     0
# 0  10
#     0
# 0  20
#     0
# 0  30
# [('Produit 1',     0
# 0  10), ('Produit 2',     0
# 0  20), ('Produit 3',     0
# 0  30)]

# %%
# Étape 3 : Conversion des prix en dollars
for i, (name, price) in enumerate(products):
    euro_price = price.str.re
    dollar_price = euro_price * 1.2
    products_list[i] = (name, f"{dollar_price}$")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[8], line 3
#       1 # Étape 3 : Conversion des prix en dollars
#       2 for i, (name, price) in enumerate(products):
# ----> 3     euro_price = price.str.re
#       4     dollar_price = euro_price * 1.2
#       5     products_list[i] = (name, f"{dollar_price}$")
#
# File ~\AppData\Roaming\Python\Python312\site-packages\bs4\element.py:984, in NavigableString.__getattr__(self, attr)
#     982     return self
#     983 else:
# --> 984     raise AttributeError(
#     985         "'%s' object has no attribute '%s'" % (
#     986             self.__class__.__name__, attr))
#
# AttributeError: 'NavigableString' object has no attribute 'str'

# %%
# Out:
# Titre de la page : Exercice extraction HTML
# Texte de la balise h1 : Bienvenue sur notre site web
# Liste des produits : [('Produit 1', 'Prix : 10â‚¬'), ('Produit 2', 'Prix : 20â‚¬'), ('Produit 3', 'Prix : 30â‚¬')]
# Liste des descriptions de produits : ['Description : Lorem ipsum dolor sit amet, consectetur adipiscing elit.', 'Description : Sed do eiusmod tempor incididunt ut labore et dolore magna aliqua.', 'Description : Ut enim ad minim veniam, quis nostrud exercitation ullamco laboris nisi ut aliquip ex ea commodo consequat.']
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[10], line 35
#      33 # Étape 3 : Conversion des prix en dollars
#      34 for i, (name, price) in enumerate(products_list):
# ---> 35     euro_price = int(price.split()[2].replace("[â‚¬]",""))
#      36     dollar_price = euro_price * 1.2
# ...
